# %% [markdown]
# # Classifiers

# %% [markdown]
# - **Releases:** [v0.2.1](https://github.com/f-marchi/alma-classifier/releases/tag/v0.2.1) (ALMA Subtype v2), [v0.1.4](https://github.com/f-marchi/alma-classifier/releases/tag/v0.1.4) (original publication)
#
# - **Python package:** https://pypi.org/project/alma-classifier/
#
# - **Docker images:** https://hub.docker.com/r/fmarchi/alma-classifier (latest: `0.2.1`; legacy: `0.1.4`)
#
# - **Models:** ALMA Subtype (27 acute leukemia subtypes), 38CpG AML Signature; AML Epigenomic Risk (v0.1.4 only)
#
# - **Datasets:** [Methylation](https://github.com/f-marchi/ALMA/releases/tag/v0.2.0), [Clinical](https://static-content.springer.com/esm/art%3A10.1038%2Fs41467-025-62005-4/MediaObjects/41467_2025_62005_MOESM4_ESM.xlsx)

# %% [markdown]
# ## Watermark

# %%
# %load_ext watermark

# %%
# watermark with all libraries used in this notebook and add date
# %watermark -v -a Francisco_Marchi@Lamba_Lab_UF -d -m -r -u
# Out:
# Author: Francisco_Marchi@Lamba_Lab_UF
#
# Last updated: 2025-11-28
#
# Python implementation: CPython
# Python version       : 3.10.13
# IPython version      : 8.27.0
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 6.6.87.1-microsoft-standard-WSL2
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 32
# Architecture: 64bit
#
# Git repo: git@github.com:f-marchi/ALMA.git
