# %% [markdown]
# # Px Score Discovery OS - Updated Risk
#
# ```{contents}
# ```

# %% [markdown]
# ## Where the data at?

# %%
import pandas as pd
import sys
sys.path.append('../')

mount = '/mnt/d/'
input_path = '/mnt/d/MethylScore/Intermediate_Files/'
output_path = '/mnt/d/MethylScore/Processed_Data/'
zhou2016_probes_path = '/mnt/d/MethylScore/UnreliableProbesList_Zhou2016/EPIC.anno.GRCh38.tsv'

# %% [markdown]
# ## Load Data

# %%
# read top CpGs selected from previous code file (univariate cox-ph EWAS)
ewas_top_cpgs = pd.read_csv(output_path+'ewas_dmr/ewas_top_cpgs_os.csv', index_col=0)

# Load clinical data
discovery_clinical_data = pd.read_csv(input_path+'discovery_clinical_data.csv',
                                      low_memory=False, index_col=0).loc[ewas_top_cpgs.index]

# save clinical data
discovery_clinical_data.to_excel('../data/ewas_top_cpgs_clinical_data_discovery.xlsx')

print(
    f' Dataset (df) contains {ewas_top_cpgs.shape[1]} columns (5mC nucleotides/probes) and {ewas_top_cpgs.shape[0]} rows (samples).')
# Out:
#  Dataset (df) contains 189 columns (5mC nucleotides/probes) and 940 rows (samples).

# %% [markdown]
# ## Standardize Data

# %% [markdown]
# Standardize the data so that mean becomes 0 and standard deviation becomes 1.
#
# This is done to avoid biasing the model towards features with large values.

# %%
def standardize_data(df, reference_df):
    """Standardize data using mean and standard deviation of reference dataset"""

    # Keep only columns that are in both datasets
    reference_df = reference_df.loc[:, df.columns]

    # Standardize data
    df = (df - reference_df.mean()) / reference_df.std()

    return df

# Standardize data
x_test_m_z = standardize_data(df= ewas_top_cpgs, reference_df= ewas_top_cpgs)

# Save standardized data
# x_test_m_z.to_excel('../data/ewas_top_167_cpgs_M-Values_standardized_discovery_cohort.xlsx')

# %% [markdown]
# ## Perform multivariate CoxPH-Lasso

# %%
# Import functions to clean up clinical data
import sys
sys.path.append('../')
from source.cox_lasso_functions import *

# raw_coefs = train_coxph_lasso(df=discovery_clinical_data,
#                                 event= 'os.evnt',
#                                 time= 'os.time',
#                                 train_x=x_test_m_z,
#                                 cv_n_split=10,
#                                 loops=1000)
# raw_coefs.to_csv(output_path + 'multivariate_cox_lasso/ewas_cog_os_raw_coefs_newrisk.csv')


raw_coefs = pd.read_csv(output_path + 'multivariate_cox_lasso/ewas_cog_os_raw_coefs_newrisk.csv', index_col=0)
# Out:
# Running Cox-Lasso through 1000 loops:
#   0%|          | 0/1000 [00:00<?, ?it/s]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   0%|          | 1/1000 [00:05<1:31:00,  5.47s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   0%|          | 2/1000 [00:10<1:22:50,  4.98s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   0%|          | 3/1000 [00:14<1:18:35,  4.73s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   0%|          | 4/1000 [00:19<1:17:10,  4.65s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   0%|          | 5/1000 [00:23<1:16:34,  4.62s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   1%|          | 6/1000 [00:28<1:15:44,  4.57s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   1%|          | 7/1000 [00:32<1:14:55,  4.53s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   1%|          | 8/1000 [00:37<1:14:30,  4.51s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   1%|          | 9/1000 [00:41<1:14:01,  4.48s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   1%|          | 10/1000 [00:45<1:14:13,  4.50s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   1%|          | 11/1000 [00:50<1:15:10,  4.56s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   1%|          | 12/1000 [00:55<1:14:56,  4.55s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   1%|▏         | 13/1000 [00:59<1:14:59,  4.56s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   1%|▏         | 14/1000 [01:04<1:15:15,  4.58s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   2%|▏         | 15/1000 [01:09<1:15:27,  4.60s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   2%|▏         | 16/1000 [01:13<1:15:42,  4.62s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   2%|▏         | 17/1000 [01:18<1:15:11,  4.59s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   2%|▏         | 18/1000 [01:22<1:15:49,  4.63s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   2%|▏         | 19/1000 [01:27<1:17:08,  4.72s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   2%|▏         | 20/1000 [01:32<1:17:40,  4.76s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   2%|▏         | 21/1000 [01:37<1:17:29,  4.75s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   2%|▏         | 22/1000 [01:42<1:17:32,  4.76s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   2%|▏         | 23/1000 [01:47<1:17:41,  4.77s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   2%|▏         | 24/1000 [01:52<1:19:34,  4.89s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   2%|▎         | 25/1000 [01:56<1:18:21,  4.82s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   3%|▎         | 26/1000 [02:01<1:16:32,  4.71s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   3%|▎         | 27/1000 [02:06<1:16:33,  4.72s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   3%|▎         | 28/1000 [02:10<1:17:13,  4.77s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   3%|▎         | 29/1000 [02:15<1:18:14,  4.83s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   3%|▎         | 30/1000 [02:20<1:19:10,  4.90s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   3%|▎         | 31/1000 [02:25<1:19:35,  4.93s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   3%|▎         | 32/1000 [02:30<1:18:02,  4.84s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   3%|▎         | 33/1000 [02:35<1:17:14,  4.79s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   3%|▎         | 34/1000 [02:40<1:17:36,  4.82s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   4%|▎         | 35/1000 [02:44<1:16:57,  4.79s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   4%|▎         | 36/1000 [02:49<1:15:29,  4.70s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   4%|▎         | 37/1000 [02:54<1:16:03,  4.74s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   4%|▍         | 38/1000 [02:58<1:15:44,  4.72s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   4%|▍         | 39/1000 [03:03<1:15:02,  4.68s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   4%|▍         | 40/1000 [03:08<1:15:30,  4.72s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   4%|▍         | 41/1000 [03:12<1:14:59,  4.69s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   4%|▍         | 42/1000 [03:17<1:14:27,  4.66s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   4%|▍         | 43/1000 [03:22<1:14:19,  4.66s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   4%|▍         | 44/1000 [03:26<1:14:05,  4.65s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   4%|▍         | 45/1000 [03:31<1:14:29,  4.68s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   5%|▍         | 46/1000 [03:36<1:15:34,  4.75s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   5%|▍         | 47/1000 [03:41<1:16:05,  4.79s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   5%|▍         | 48/1000 [03:45<1:14:26,  4.69s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   5%|▍         | 49/1000 [03:50<1:14:58,  4.73s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   5%|▌         | 50/1000 [03:55<1:15:27,  4.77s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   5%|▌         | 51/1000 [04:00<1:15:46,  4.79s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# ...
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#  98%|█████████▊| 982/1000 [1:20:00<01:27,  4.87s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#  98%|█████████▊| 983/1000 [1:20:05<01:21,  4.78s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#  98%|█████████▊| 984/1000 [1:20:10<01:17,  4.84s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#  98%|█████████▊| 985/1000 [1:20:14<01:12,  4.84s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#  99%|█████████▊| 986/1000 [1:20:19<01:08,  4.91s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#  99%|█████████▊| 987/1000 [1:20:24<01:03,  4.90s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#  99%|█████████▉| 988/1000 [1:20:29<00:58,  4.84s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#  99%|█████████▉| 989/1000 [1:20:34<00:53,  4.82s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#  99%|█████████▉| 990/1000 [1:20:39<00:48,  4.82s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#  99%|█████████▉| 991/1000 [1:20:43<00:43,  4.81s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#  99%|█████████▉| 992/1000 [1:20:48<00:38,  4.80s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#  99%|█████████▉| 993/1000 [1:20:53<00:33,  4.78s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#  99%|█████████▉| 994/1000 [1:20:58<00:28,  4.80s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# 100%|█████████▉| 995/1000 [1:21:03<00:24,  4.87s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# 100%|█████████▉| 996/1000 [1:21:08<00:20,  5.03s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# 100%|█████████▉| 997/1000 [1:21:13<00:15,  5.02s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# 100%|█████████▉| 998/1000 [1:21:18<00:10,  5.02s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# 100%|█████████▉| 999/1000 [1:21:23<00:05,  5.06s/it]/home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /home/fmarchi/projects/MethylScore/Code/.venv_py38/lib/python3.8/site-packages/sklearn/pipeline.py:405: UserWarning: all coefficients are zero, consider decreasing alpha.
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# 100%|██████████| 1000/1000 [1:21:29<00:00,  4.89s/it]
# Cox-Lasso Trained Successfuly!
# Selected alpha value: [0.01795433858813518]

# %% [markdown]
# ### Set Threshold

# %%
mean_coefs = set_cutoff(coefs=raw_coefs,threshold=0.99)
                                
plot_nonzero_coef_freq(raw_coefs, mean_coefs, threshold=0.99, savefig=False, fig_path=None, figsize=(10,4))

# %% [markdown]
# ### Save table of CpGs coefficients with EWAS results

# %%
# Load `ewas_cpgs_top_OS_with_EFSinfo.xlsx`
# ewas_cpgs_top_OS_with_EFSinfo = pd.read_excel('../data/ewas_cpgs_top_OS_with_EFSinfo.xlsx', index_col=0)\
#     .join(mean_coefs.to_frame('MethylScoreAML Px Coefs')).sort_values('MethylScoreAML Px Coefs', ascending=False)\
#         .to_excel('../data/ewas_cpgs_top_OS_with_EFSinfo_with_MethylScoreAML_Px_Coefs.xlsx')

# %% [markdown]
# ## Generate Model Results

# %% [markdown]
# ### Discovery Dataset

# %%
score_name = 'MethylScoreAML_Px'

df, threshold = generate_coxph_score(coef_mean=mean_coefs,
                                        x=x_test_m_z,
                                        df=discovery_clinical_data,
                                        score_name=score_name,
                                        train_test="train",
                                        rpart_outcome='os.time')

df.to_excel(output_path + 'multivariate_cox_lasso/ewas_cog_os_MethylScoreAML_Px.xlsx')
# Out:
# Continuous score cut at the value of 0.4936

# %%
sns.histplot(data=df,x=score_name, bins=50, hue = score_name + ' Categorical' )

# add vertical line at threshold and third quartile
plt.axvline(threshold ,color='blue', linestyle='--')
plt.axvline(df[score_name].quantile(0.6), color='red', linestyle='--')


# add legend
plt.legend({'RPart':threshold, '60%-40%':df[score_name].quantile(0.6)})
plt.title('Distribution of ' + score_name + ' in COG trials')
# Out:
# Text(0.5, 1.0, 'Distribution of MethylScoreAML_Px in COG trials')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# create scatterplot 
sns.scatterplot(data=df, x=score_name, y='os.time', alpha=0.8)

# use hexbin plot to show density
ax = plt.gca()
ax.hexbin(df[score_name], df['os.time'], gridsize=50, cmap='Blues')

# add title
plt.title('Hexbin Scatterplot of {} in COG trials'.format(score_name)) 

# add vertical line at threshold
plt.axvline(threshold, color='red', linestyle='--', label='Threshold')
plt.legend()

# save plot as png
# plt.savefig(path + '/Hexbin_Scatterplot_{}_efs.time_{}.png'.format(score_name, len(df)), 
#             bbox_inches='tight', dpi=300)

plt.show()

# %% [markdown]
# ### Kaplan-Meier Plots

# %% [markdown]
# #### Overall study population

# %%
# Import Plotting Functions
from source.data_visualization_functions import *

draw_kaplan_meier(scorename=score_name,
                        df=df,
                        save_plot=False,
                        save_survival_table=True,
                        add_risk_counts=False,
                        trialname='COG trials')

# %% [markdown]
# #### Per risk group

# %%
draw_kaplan_meier(scorename=score_name,
                        df=df[df['Risk Group'] == 'High Risk'],
                        save_plot=False,
                        save_survival_table=False,
                        add_risk_counts=False,
                        trialname='COG trials, High Risk Group')

draw_kaplan_meier(scorename=score_name,
                        df=df[df['Risk Group'] == 'Low Risk'],
                        save_plot=False,
                        save_survival_table=False,
                        add_risk_counts=False,
                        trialname='COG trials, Low Risk Group')

draw_kaplan_meier(scorename=score_name,
                        df=df[df['Risk Group'] == 'Standard Risk'],
                        save_plot=False,
                        save_survival_table=False,
                        add_risk_counts=False,
                        trialname='COG trials, Standard Risk Group')

# %% [markdown]
# ### Updated risk group

# %%
new_risk = pd.read_csv(input_path + 'updated_risk_group_COG_RR_1-10-2024/COG_risk_added_v2_cleanedFM.csv',
                       index_col=0,)
                       
df2 = df.join(new_risk[['Cyto/Molecular Risk']])

draw_kaplan_meier(scorename=score_name,
                        df=df2[df2['Cyto/Molecular Risk'] == 'High'],
                        save_plot=False,
                        save_survival_table=False,
                        add_risk_counts=False,
                        trialname='COG trials, High Risk Group')

draw_kaplan_meier(scorename=score_name,
                        df=df2[df2['Cyto/Molecular Risk'] == 'Low'],
                        save_plot=False,
                        save_survival_table=False,
                        add_risk_counts=False,
                        trialname='COG trials, Low Risk Group')

draw_kaplan_meier(scorename=score_name,
                        df=df2[df2['Cyto/Molecular Risk'] == 'Standard'],
                        save_plot=False,
                        save_survival_table=False,
                        add_risk_counts=False,
                        trialname='COG trials, Standard Risk Group')

# %% [markdown]
# ### Forest Plots

# %% [markdown]
# #### With MRD 1

# %%
draw_forest_plot(time='os.time',
                    event='os.evnt',
                    df=df,
                    trialname='COG trials:',
                    scorename=score_name,
                    save_plot=False)

draw_forest_plot(time='efs.time',
                    event='efs.evnt',
                    df=df,
                    trialname='COG trials:',
                    scorename=score_name,
                    save_plot=False)

# %% [markdown]
# #### Without MRD 1

# %%
draw_forest_plot_noMRD(time='os.time',
                    event='os.evnt',
                    df=df,
                    trialname='COG trials:',
                    scorename=score_name,
                    save_plot=False)

draw_forest_plot_noMRD(time='efs.time',
                    event='efs.evnt',
                    df=df,
                    trialname='COG trials:',
                    scorename=score_name,
                    save_plot=False)

# %% [markdown]
# ### ROC AUC

# %%
# Your current preprocessing
df['Risk Group bins'] = df['Risk Group'].replace({'Low Risk':0, 'Standard Risk':0.5, 'High Risk':1})
df['MRD 1 bins'] = df['MRD 1 Status'].replace({'Negative':0, 'Positive':1})
df2 = df[['os.evnt', 'MethylScoreAML_Px_cat_bin', 'Risk Group bins', 'MRD 1 bins']].dropna()

# rename column `MethylScoreAML_Px_cat_bin` to `MethylScoreAML Px`
df2 = df2.rename(columns={'MethylScoreAML_Px_cat_bin':'MethylScoreAML_Px'})

# Add new columns based on standardized values
df2['MRD1 + Risk Group'] = df['MRD 1 bins'] + df['Risk Group bins']
df2['MRD1 + Risk Group + MethylScore'] = df['MRD 1 bins'] + df['Risk Group bins'] + df['MethylScoreAML_Px']


import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import LabelBinarizer

def plot_roc_auc(df, score_columns, outcome_column, trial_name='discovery cohort'):
    """
    Plots the ROC AUC curves for multiple models given a dataframe and multiple score columns.
    
    Parameters:
    - df (pd.DataFrame): Dataframe containing the score and outcome columns.
    - score_columns (list of str): List of names of columns that contain the scores.
    - outcome_column (str): The name of the column that contains the true outcomes.
    
    Returns:
    None
    """
    
    plt.figure()
    plt.title('ROC AUC in ' + trial_name + ', n={}'.format(len(df)))
    
    # plot random guessing line
    plt.plot([0, 1], [0, 1], 'r--')

    # binarize the outcome variable
    lb = LabelBinarizer()
    lb.fit(df[outcome_column])
    y = lb.transform(df[outcome_column])
    
    # Loop over score_columns to plot multiple ROC curves
    for score_column in score_columns:
        
        # calculate the fpr and tpr for all thresholds of the classification
        fpr, tpr, threshold = roc_curve(y, df[score_column])
        roc_auc = auc(fpr, tpr)
        
        # plot ROC curve for this score_column
        plt.plot(fpr, tpr, label=f'{score_column} AUC = %0.2f' % roc_auc)

    # set x and y limits
    plt.xlim([0, 1])
    plt.ylim([0, 1])

    # set x and y labels
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')

    # add legend
    plt.legend(loc='lower right')
    plt.show()

# Example Usage:
score_columns = ['MethylScoreAML_Px', 'Risk Group bins', 'MRD 1 bins', 'MRD1 + Risk Group', 'MRD1 + Risk Group + MethylScore']
outcome_column = 'os.evnt'
plot_roc_auc(df2, score_columns, outcome_column)

# %% [markdown]
# ### Box Plots

# %%
draw_boxplot(df=discovery_clinical_data,x='Risk Group', y=score_name,
                order=['High Risk', 'Standard Risk', 'Low Risk'],
                trialname='COG', hue=score_name + ' Categorical',
                save_plot=False, figsize=None)

draw_boxplot(df=discovery_clinical_data,x='MRD 1 Status', y=score_name,
                order=['Positive','Negative'],
                trialname='COG', hue=score_name + ' Categorical',
                save_plot=False, figsize=None)

draw_boxplot(df=discovery_clinical_data,x='Primary Cytogenetic Code', y=score_name,
                order='auto',
                trialname='COG', hue=score_name + ' Categorical',
                save_plot=False, figsize=None)
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# High Risk vs. Standard Risk: Kruskal-Wallis independent samples (pairwise between groups) with Bonferroni correction, P_val:1.011e-01 Stat=4.509e+00
# Standard Risk vs. Low Risk: Kruskal-Wallis independent samples (pairwise between groups) with Bonferroni correction, P_val:2.855e-77 Stat=3.484e+02
# High Risk vs. Low Risk: Kruskal-Wallis independent samples (pairwise between groups) with Bonferroni correction, P_val:6.482e-33 Stat=1.450e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Positive vs. Negative: Kruskal-Wallis independent samples (pairwise between groups) with Bonferroni correction, P_val:5.743e-06 Stat=2.057e+01

# %% [markdown]
# ### Stacked Bar Plots

# %%
draw_stacked_barplot(df=discovery_clinical_data,x='MRD 1 Status', y=score_name,
             order=['Positive','Negative'],
             trialname='COG', hue=score_name + ' Categorical',
             save_plot=False, figsize=None)

draw_stacked_barplot(df=discovery_clinical_data,x='Risk Group', y=score_name,
                order=['High Risk', 'Standard Risk', 'Low Risk'],
                trialname='COG', hue=score_name + ' Categorical',
                save_plot=False, figsize=None, fontsize=9)

draw_stacked_barplot(df=discovery_clinical_data,x='Primary Cytogenetic Code', y=score_name,
                order='auto',
                trialname='COG', hue=score_name + ' Categorical',
                save_plot=False, figsize=None, fontsize=8)

# %% [markdown]
# ### Patient Characteristics Table

# %% [markdown]
# #### Overall study population

# %%
from tableone import TableOne

columns = ['Age (years)','Age group (years)','Sex','Race or ethnic group',
            'Hispanic or Latino ethnic group', 'MRD 1 Status',
            'Leucocyte counts (10⁹/L)', 'BM Leukemic blasts (%)',
            'Risk Group', 'Clinical Trial','FLT3 ITD']

discovery_clinical_data['Age (years)'] = discovery_clinical_data['Age (years)'].astype(float)

mytable_cog = TableOne(discovery_clinical_data, columns,
                        overall=False, missing=True,
                        pval=False, pval_adjust=False,
                        htest_name=True,dip_test=True,
                        tukey_test=True, normal_test=True,

                        order={'FLT3 ITD':['Yes','No'],
                                'Race or ethnic group':['White','Black or African American','Asian'],
                                'MRD 1 Status': ['Positive'],
                                'Risk Group': ['High Risk', 'Standard Risk'],
                                'FLT3 ITD': ['Yes'],
                                'Leucocyte counts (10⁹/L)': ['≥30'],
                                'Age group (years)': ['≥10']})

# mytable_cog.to_csv(output_path + 'multivariate_cox_lasso/tableone_discovery_cohort.csv')

mytable_cog.tabulate(tablefmt="html", 
                        headers=[score_name,"",'Missing','Discovery Cohort','Low','p-value','Statistical Test'])
# Out:
# '<table>\n<thead>\n<tr><th>MethylScoreAML_Px                     </th><th>                                         </th><th>Missing  </th><th>Discovery Cohort  </th></tr>\n</thead>\n<tbody>\n<tr><td>n                                     </td><td>                                         </td><td>         </td><td>940               </td></tr>\n<tr><td>Age (years), mean (SD)                </td><td>                                         </td><td>0        </td><td>9.4 (6.3)         </td></tr>\n<tr><td>Age group (years), n (%)              </td><td>≥10                                      </td><td>0        </td><td>458 (48.7)        </td></tr>\n<tr><td>                                      </td><td>&lt;10                                      </td><td>         </td><td>482 (51.3)        </td></tr>\n<tr><td>Sex, n (%)                            </td><td>Female                                   </td><td>0        </td><td>466 (49.6)        </td></tr>\n<tr><td>                                      </td><td>Male                                     </td><td>         </td><td>474 (50.4)        </td></tr>\n<tr><td>Race or ethnic group, n (%)           </td><td>White                                    </td><td>64       </td><td>692 (79.0)        </td></tr>\n<tr><td>                                      </td><td>Black or African American                </td><td>         </td><td>102 (11.6)        </td></tr>\n<tr><td>                                      </td><td>Asian                                    </td><td>         </td><td>43 (4.9)          </td></tr>\n<tr><td>                                      </td><td>American Indian or Alaska Native         </td><td>         </td><td>5 (0.6)           </td></tr>\n<tr><td>                                      </td><td>Native Hawaiian or other Pacific Islander</td><td>         </td><td>6 (0.7)           </td></tr>\n<tr><td>                                      </td><td>Other                                    </td><td>         </td><td>28 (3.2)          </td></tr>\n<tr><td>Hispanic or Latino ethnic group, n (%)</td><td>Hispanic or Latino                       </td><td>29       </td><td>184 (20.2)        </td></tr>\n<tr><td>                                      </td><td>Not Hispanic or Latino                   </td><td>         </td><td>727 (79.8)        </td></tr>\n<tr><td>MRD 1 Status, n (%)                   </td><td>Positive                                 </td><td>119      </td><td>258 (31.4)        </td></tr>\n<tr><td>                                      </td><td>Negative                                 </td><td>         </td><td>563 (68.6)        </td></tr>\n<tr><td>Leucocyte counts (10⁹/L), n (%)       </td><td>≥30                                      </td><td>0        </td><td>463 (49.3)        </td></tr>\n<tr><td>                                      </td><td>&lt;30                                      </td><td>         </td><td>477 (50.7)        </td></tr>\n<tr><td>BM Leukemic blasts (%), mean (SD)     </td><td>                                         </td><td>67       </td><td>63.8 (24.5)       </td></tr>\n<tr><td>Risk Group, n (%)                     </td><td>High Risk                                </td><td>14       </td><td>128 (13.8)        </td></tr>\n<tr><td>                                      </td><td>Standard Risk                            </td><td>         </td><td>453 (48.9)        </td></tr>\n<tr><td>                                      </td><td>Low Risk                                 </td><td>         </td><td>345 (37.3)        </td></tr>\n<tr><td>Clinical Trial, n (%)                 </td><td>AAML03P1                                 </td><td>0        </td><td>36 (3.8)          </td></tr>\n<tr><td>                                      </td><td>AAML0531                                 </td><td>         </td><td>507 (53.9)        </td></tr>\n<tr><td>                                      </td><td>AAML1031                                 </td><td>         </td><td>397 (42. ...

# %% [markdown]
# #### By MethylScore category

# %%
from tableone import TableOne

columns = ['Age (years)','Age group (years)','Sex','Race or ethnic group',
            'Hispanic or Latino ethnic group', 'MRD 1 Status',
            'Leucocyte counts (10⁹/L)', 'BM Leukemic blasts (%)',
            'Risk Group', 'Clinical Trial','FLT3 ITD']

discovery_clinical_data['Age (years)'] = discovery_clinical_data['Age (years)'].astype(float)

mytable_cog = TableOne(discovery_clinical_data, columns,
                        overall=False, missing=True,
                        pval=True, pval_adjust=False,
                        htest_name=True,dip_test=True,
                        tukey_test=True, normal_test=True,

                        order={'FLT3 ITD':['Yes','No'],
                                'Race or ethnic group':['White','Black or African American','Asian'],
                                'MRD 1 Status': ['Positive'],
                                'Risk Group': ['High Risk', 'Standard Risk'],
                                'FLT3 ITD': ['Yes'],
                                'Leucocyte counts (10⁹/L)': ['≥30'],
                                'Age group (years)': ['≥10']},
                        groupby=score_name + ' Categorical')

mytable_cog.to_csv(output_path + 'multivariate_cox_lasso/tableone_discovery_methylscoreaml_px.csv')
mytable_cog.to_excel('../data/tableone_discovery_methylscoreaml_px.xlsx')

mytable_cog.tabulate(tablefmt="html", 
                        headers=[score_name,"",'Missing','High','Low','p-value','Statistical Test'])
# Out:
# '<table>\n<thead>\n<tr><th>MethylScoreAML_Px                     </th><th>                                         </th><th>Missing  </th><th>High       </th><th>Low        </th><th>p-value  </th><th>Statistical Test                         </th></tr>\n</thead>\n<tbody>\n<tr><td>n                                     </td><td>                                         </td><td>         </td><td>707        </td><td>233        </td><td>         </td><td>                                         </td></tr>\n<tr><td>Age (years), mean (SD)                </td><td>                                         </td><td>0        </td><td>9.6 (6.2)  </td><td>8.7 (6.6)  </td><td>0.058    </td><td>Two Sample T-test                        </td></tr>\n<tr><td>Age group (years), n (%)              </td><td>≥10                                      </td><td>0        </td><td>348 (49.2) </td><td>110 (47.2) </td><td>0.647    </td><td>Chi-squared                              </td></tr>\n<tr><td>                                      </td><td>&lt;10                                      </td><td>         </td><td>359 (50.8) </td><td>123 (52.8) </td><td>         </td><td>                                         </td></tr>\n<tr><td>Sex, n (%)                            </td><td>Female                                   </td><td>0        </td><td>357 (50.5) </td><td>109 (46.8) </td><td>0.364    </td><td>Chi-squared                              </td></tr>\n<tr><td>                                      </td><td>Male                                     </td><td>         </td><td>350 (49.5) </td><td>124 (53.2) </td><td>         </td><td>                                         </td></tr>\n<tr><td>Race or ethnic group, n (%)           </td><td>White                                    </td><td>64       </td><td>521 (79.1) </td><td>171 (78.8) </td><td>0.095    </td><td>Chi-squared (warning: expected count &lt; 5)</td></tr>\n<tr><td>                                      </td><td>Black or African American                </td><td>         </td><td>68 (10.3)  </td><td>34 (15.7)  </td><td>         </td><td>                                         </td></tr>\n<tr><td>                                      </td><td>Asian                                    </td><td>         </td><td>36 (5.5)   </td><td>7 (3.2)    </td><td>         </td><td>                                         </td></tr>\n<tr><td>                                      </td><td>American Indian or Alaska Native         </td><td>         </td><td>4 (0.6)    </td><td>1 (0.5)    </td><td>         </td><td>                                         </td></tr>\n<tr><td>                                      </td><td>Native Hawaiian or other Pacific Islander</td><td>         </td><td>6 (0.9)    </td><td>           </td><td>         </td><td>                                         </td></tr>\n<tr><td>                                      </td><td>Other                                    </td><td>         </td><td>24 (3.6)   </td><td>4 (1.8)    </td><td>         </td><td>                                         </td></tr>\n<tr><td>Hispanic or Latino ethnic group, n (%)</td><td>Hispanic or Latino                       </td><td>29       </td><td>137 (19.9) </td><td>47 (21.1)  </td><td>0.779    </td><td>Chi-squared                              </td></tr>\n<tr><td>                                      </td><td>Not Hispanic or Latino                   </td><td>         </td><td>551 (80.1) </td><td>176 (78.9) </td><td>         </td><td>                                         </td></tr>\n<tr><td>MRD 1 Status, n (%)                   </td><td>Positive                                 </td><td>119      </td><td>178 (28.5) </td><td>80 (40.8)  </td><td>0.002    </td><td>Chi-squared                              </td></tr>\n<tr><td>                                      </td><td>Negative                                 </td><td>         </td><td>447 (71.5) </td><td>116 (59.2) </td><td>         </td><td>                                ...

# %% [markdown]
# ## Fetch gene annotation

# %%
# Load manifest
zhou2016_probes = pd.read_csv(zhou2016_probes_path,sep='\t',
                    index_col=0)[['chrm','start', 'end', 'GeneNames','GeneClasses','CGIPosition']]

# Get probes from Zhou et al. (2016) that are in ewasOS_un.index
mean_coefs_genes = zhou2016_probes.loc[list(ewas_top_cpgs.columns)]\
                                    .join(mean_coefs.to_frame('MethylScore Coefficients'), how='left')\
                                    .sort_values(by='MethylScore Coefficients', ascending=False)

# `GeneNames`, `GeneClasses`, and `TranscriptIDs` columns contain multiple genes separated by `;` so we need to keep only the unique ones
mean_coefs_genes['GeneNames'] = mean_coefs_genes['GeneNames'].apply(lambda x: ';'.join(set(x.split(';'))))
mean_coefs_genes['GeneClasses'] = mean_coefs_genes['GeneClasses'].apply(lambda x: ';'.join(set(x.split(';'))))

# Transform `GeneNames` values separated by `;` into a list
mean_coefs_genes['GeneNames'] = mean_coefs_genes['GeneNames'].apply(lambda x: x.split(';'))

# If there are multiple genes in `GeneNames` or `GeneClasses`, we will add one row for each gene
mean_coefs_genes = mean_coefs_genes.explode('GeneNames')

# Save the dataframe to a CSV file
mean_coefs_genes.to_excel('../data/MethylScoreAML_Px_167_cpg_genes.xlsx')
mean_coefs_genes.to_csv(output_path + 'multivariate_cox_lasso/methylScore_coxph_167_cpg_signature.csv')


from itables import show

show(mean_coefs_genes, classes="display nowrap cell-border")
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="15ad072c-1269-4ac9-b6c3-71822210148b" class="display nowrap cell-border"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>chrm</th>
#       <th>start</th>
#       <th>end</th>
#       <th>GeneNames</th>
#       <th>GeneClasses</th>
#       <th>CGIPosition</th>
#       <th>MethylScore Coefficients</th>
#     </tr>
#     <tr>
#       <th>probeID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [["cg20219911", "chr3", 52779635, 52779637, "ITIH1", "protein_coding", ".", 0.108295], ["cg02678414", "chr16", 2159838, 2159840, "TRAF7", "protein_coding", "S_Shelf", 0.104095], ["cg00151914", "chr17", 35731530, 35731532, "RASL10B", "protein_coding", "Island", 0.083273], ["cg00151914", "chr17", 35731530, 35731532, "TAF15", "protein_coding", "Island", 0.083273], ["cg14978242", "chr5", 80205311, 80205313, "SERINC5", "protein_coding", ".", 0.081108], ["cg25035655", "chr11", 68751776, 68751778, "MTL5", "protein_coding", "S_Shore", 0.081062], ["cg14882966", "chr2", 3651762, 3651764, ".", ".", "Island", 0.079024], ["cg17099306", "chr13", 49549508, 49549510, "RCBTB1", "protein_coding", ".", 0.069778], ["cg10089193", "chr16", 1090938, 1090940, "C1QTNF8", "protein_coding", "S_Shore", 0.067037], ["cg16147063", "chr14", 81221539, 81221541, "GTF2A1", "protein_coding;antisense", "Island", 0.064787], ["cg16147063", "chr14", 81221539, 81221541, "CTD-2506P8.6", "protein_coding;antisense", "Island", 0.064787], ["cg09890699", "chr1", 54356179, 54356181, "SSBP3", "protein_coding", "N_Shore", 0.060028], ["cg17389427", "chr3", 129612142, 129612144, ".", ".", ".", 0.059668], ["cg04665204", "chr17", 81453397, 81453399, "BAHCC1", "protein_coding", "Island", 0.049729], ["cg00532502", "chr1", 246789970, 246789972, "LINC01341", "processed_transcript;unitary_pseudogene", "S_Shore", 0.04281], ["cg00532502", "chr1", 246789970, 246789972, "KIF28P", "processed_transcript;unitary_pseudogene", "S_Shore", 0.04281], ["cg05800336", "chr10", 131453805, 131453807, ".", ".", ".", 0.040324], ["cg17669009", "chr19", 51417630, 51417632, "SIGLEC10", "protein_coding", ".", 0.037699], ["cg04663203", "chr17", 47851211, 47851213, "SP6", "protein_coding", "Island", 0.035529], ["cg19706516", "chr1", 151131392, 151131394, "RP11-68I18.10", "sense_overlapping", "Island", 0.026956], ["cg05348324", "chr11", 119797455, 119797457, ".", ".", ".", 0.026123], ["cg19839026", "chr14", 50943782, 50943784, "PYGL", "protein_coding", "N_Shore", 0.013157], ["cg04516952", "chr19", 50968785, 50968787, "CTB-147C22.9", "protein_coding;antisense", ".", 0.008944], ["cg04516952", "chr19", 50968785, 50968787, "KLK6", "protein_coding;antisense", ".", 0.008944], ["cg18072388", "chr19", 10323084, 10323086, "RAVER1", "protein_coding", "N_Shore", 0.003137], ["cg13440692", "chr1", 1250976, 1250978, "RP5-902P8.12", "lincRNA", "N_Shelf", 0.002857], ["cg10098541", "chr3", 123066802, 123066804, "PDIA5", "protein_coding", "N_Shore", -0.000913], ["cg00945409", "chr10", 78977907, 78977909, "ZMIZ1-AS1", "antisense", "S_Shelf", -0.001331], ["cg04092699", "chr2", 76748093, 76748095, "LRRTM4", "protein_coding", ".", -0.003507], ["cg06785302", "chr8", 118111811, 118111813, "EXT1", "protein_coding", "Island", -0.004782], ["cg13360395", "chr2", 123907703, 123907705, ".", ".", ".", -0.006694], ["cg03601372", "chr19", 36776123, 36776125, "CTD-2162K18.3", "lincRNA", "Island", -0.008281], ["cg03601372", "chr19", 36776123, 36776125, "CTD-2162K18.4", "lincRNA", "Island", -0.008281], ["cg04205653", "chr21", 44805974, 44805976, "SUMO3", "protein_coding", "S_Shelf", -0.009028], ["cg11064395", "chr6", 31407526, 31407528, "MICA", "sense_overlapping;protein_coding", "S_Shelf", -0.01054], ["cg11064395", "chr6", 31407526, 31407528, "HCP5", "sense_overlapping;protein_coding", "S_Shelf", -0.01054], ["cg23458843", "chr12", 57742661, 57742663, "TSPAN31", "protein_coding", "S_Shelf", -0.013363], ["cg23458843", "chr12", 57742661, 57742663, "AGAP2", "protein_coding", "S_Shelf", -0.013363], ["cg21170304", "chr9", 135987756, 135987758, ".", ".", "N_Shelf", -0.016585], ["cg11818438", "chr8", 118904290, 118904292, ".", ".", ".", -0.016987], ["cg07080653", "chr4", 53508081, 53508083, "FIP1L1", "protein_coding;antisense", ".", -0.026076], ["cg07080653", "chr4", 53508081, 53508083, "LNX1-AS1", "protein_coding;antisense", ".", -0.026076], ["cg07080653", "chr4", 53508081, 53508083, "LNX1", "protein_coding;antisense", ".", -0.026076] ...

# %% [markdown]
# ## Watermark

# %%
# %load_ext watermark

# %%
# watermark with all libraries used in this notebook
# %watermark -v -p pandas,seaborn,matplotlib,tableone,sklearn,lifelines,statannotations -a Francisco_Marchi@Lamba_Lab_UF -d -m
# Out:
# Author: Francisco_Marchi@Lamba_Lab_UF
#
# Python implementation: CPython
# Python version       : 3.8.16
# IPython version      : 8.12.2
#
# pandas         : 2.0.2
# seaborn        : 0.12.2
# matplotlib     : 3.7.1
# tableone       : 0.7.12
# sklearn        : 1.2.2
# lifelines      : 0.27.7
# statannotations: 0.5.0
#
# Compiler    : GCC 11.3.0
# OS          : Linux
# Release     : 5.15.133.1-microsoft-standard-WSL2
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 20
# Architecture: 64bit
